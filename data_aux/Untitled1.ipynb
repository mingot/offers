# %%
using RDatasets

# %%
user_brand = readtable("user_brand.csv",allowcomments=true,header=true,separator=',')
# Out:
# DataFrame with 1600 rows, 11125 columns
# Columns:
#
# id          1600 non-null values
# 0           1600 non-null values
# 18          1600 non-null values
# 29          1600 non-null values
# 31          1600 non-null values
# 49          1600 non-null values
# 52          1600 non-null values
# 60          1600 non-null values
# 67          1600 non-null values
# 70          1600 non-null values
# 73          1600 non-null values
# 74          1600 non-null values
# 76          1600 non-null values
# 84          1600 non-null values
# 85          1600 non-null values
# 89          1600 non-null values
# 95          1600 non-null values
# 100         1600 non-null values
# 121         1600 non-null values
# 128         1600 non-null values
# 140         1600 non-null values
# 144         1600 non-null values
# 145         1600 non-null values
# 147         1600 non-null values
# 150         1600 non-null values
# 153         1600 non-null values
# 156         1600 non-null values
# ...

# %%
user_brand[1,:]
# Out:
# DataFrame with 1 rows, 11125 columns
# Columns:
#
# id          1 non-null values
# 0           1 non-null values
# 18          1 non-null values
# 29          1 non-null values
# 31          1 non-null values
# 49          1 non-null values
# 52          1 non-null values
# 60          1 non-null values
# 67          1 non-null values
# 70          1 non-null values
# 73          1 non-null values
# 74          1 non-null values
# 76          1 non-null values
# 84          1 non-null values
# 85          1 non-null values
# 89          1 non-null values
# 95          1 non-null values
# 100         1 non-null values
# 121         1 non-null values
# 128         1 non-null values
# 140         1 non-null values
# 144         1 non-null values
# 145         1 non-null values
# 147         1 non-null values
# 150         1 non-null values
# 153         1 non-null values
# 156         1 non-null values
# 157         1 non-null values
# 158         1 non-null values
# ...
